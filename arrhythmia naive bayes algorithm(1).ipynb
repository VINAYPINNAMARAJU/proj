# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd

# %%
data=pd.read_csv('data_arrhythmia.csv',delimiter=';')

# %%
data.shape
# Out:
# (452, 280)

# %%
data.head()
# Out:
#    age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
# 2   54    0     172      95           138           163           386
# 3   55    0     175      94           100           202           380
# 4   75    0     190      80            88           181           360
#
#    t_interval  p_interval  qrs    ...       KY    KZ   LA   LB LC   LD   LE  \
# 0         174         121  -16    ...      0.0   9.0 -0.9  0.0  0  0.9  2.9
# 1         149          39   25    ...      0.0   8.5  0.0  0.0  0  0.2  2.1
# 2         185         102   96    ...      0.0   9.5 -2.4  0.0  0  0.3  3.4
# 3         179         143   28    ...      0.0  12.2 -2.2  0.0  0  0.4  2.6
# 4         177         103  -16    ...      0.0  13.1 -3.6  0.0  0 -0.1  3.9
#
#      LF    LG  diagnosis
# 0  23.3  49.4          8
# 1  20.4  38.8          6
# ...

# %%
data.head(10)
# Out:
#    age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
# 2   54    0     172      95           138           163           386
# 3   55    0     175      94           100           202           380
# 4   75    0     190      80            88           181           360
# 5   13    0     169      51           100           167           321
# 6   40    1     160      52            77           129           377
# 7   49    1     162      54            78             0           376
# 8   44    0     168      56            84           118           354
# 9   50    1     167      67            89           130           383
#
#    t_interval  p_interval  qrs    ...       KY    KZ   LA   LB LC   LD   LE  \
# 0         174         121  -16    ...      0.0   9.0 -0.9  0.0  0  0.9  2.9
# ...

# %%
data.drop(["J","R'_wave","S'_wave", "AB", "AC", "AD","AE", "AF", "AG", "AL", "AN", "AO", "AP", "AR", "AS", "AT", "AZ", "AB'", "BC", "BD", "BE", "BG", "BH", "BP", "BR", "BS", "BT", "BU", 
          "CA", "CD", "CE", "Cf", "CG", "CH", "CI", "CM","CN","CP","CR","CS","CT","CU","CV","DE","DF","DG","DH","DI","DJ","DR","DS","DT","DU","DV","DY","EG",
          "EH", "EL", "ER", "ET", "EU", "EV", "EY", "EZ", "FA", "FE", "FF", "FH", "FI", "FJ", "FK", "FL", "FM", "FR", "FS", "FU", "FV", "FY", "FZ", "GA",
          "GB", "GG", "GH", "HD", "HE", "HO", "IA", "IB", "IK", "IL", "IY", "JI", "JS", "JT", "KF", "KO", "KP", "LB", "LC", "T", "P", "QRST", "heart_rate"], axis=1, inplace=True)

# %% [markdown]
# Missing data in the dataset or features containing all 0 were removed from the dataset.

# %%
data.head()
# Out:
#    age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
# 2   54    0     172      95           138           163           386
# 3   55    0     175      94           100           202           380
# 4   75    0     190      80            88           181           360
#
#    t_interval  p_interval  qrs    ...        KU   KV   KY    KZ   LA   LD  \
# 0         174         121  -16    ...      62.9 -0.3  0.0   9.0 -0.9  0.9
# 1         149          39   25    ...      43.4 -0.5  0.0   8.5  0.0  0.2
# 2         185         102   96    ...      48.2  0.9  0.0   9.5 -2.4  0.3
# 3         179         143   28    ...      68.0  0.1  0.0  12.2 -2.2  0.4
# 4         177         103  -16    ...      48.9 -0.4  0.0  13.1 -3.6 -0.1
#
#     LE    LF    LG  diagnosis
# 0  2.9  23.3  49.4          8
# 1  2.1  20.4  38.8          6
# ...

# %%
y = data.diagnosis.values
x = data.drop(["diagnosis"],axis=1)

# %% [markdown]
# Diagnosis values were loaded on y axis. The x axis was loaded with all data except diagnosis. The diagnosis feature is a feature of classes 1-16.

# %% [markdown]
# The train_test_split function randomly divides the dataset into train and test. In other words, 60% train section is not 60% from the beginning of dataset. It is the amount corresponding to 60% of all data. The expression random_state = 42 allows the same 60% and 20% sections to be used each time this function is executed. In this way, the work produced by different people at different times produces the same output. 42 is the meaning of life in the book A Hitchhiker's Guide to the Galaxy. Instead of 42, 20, 19 can also be used.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state=25)
x_train, x_validate, y_train, y_validate = train_test_split(x_train,y_train,test_size=0.25, random_state=25)

# %%
x_train.head()
# Out:
#      age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 191   60    1     160      61            81           191           354
# 230   72    0     171      74            77           172           330
# 91    64    1     155      88            82           194           342
# 273   63    1     160      63            79           141           423
# 412   41    0     170      67            96           191           368
#
#      t_interval  p_interval  qrs  ...     KT    KU   KV   KY    KZ   LA   LD  \
# 191         127          99   76  ...   21.1  30.2  0.1  0.0   7.7  0.0  0.7
# 230         140         104   33  ...   17.9  21.1  0.0  0.0   6.8  0.0  0.7
# 91          138         126   -4  ...    4.7  14.3 -0.1  0.0   4.9 -0.9  0.3
# 273         138          79   57  ...    8.5  12.3 -0.5  0.0   5.8 -1.6  0.3
# 412         202         108   62  ...   43.1  64.6 -1.5 -3.5  21.1  0.0 -0.1
#
#       LE    LF    LG
# 191  0.7  21.5  27.9
# 230  0.8  25.8  31.4
# ...

# %%
x_test.head()
# Out:
#      age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 405   21    1     156      44            78           151           363
# 125   25    1     162      78            77           141           378
# 135   40    0     172      60            87           146           352
# 421   63    1     167      68            94           175           439
# 250   15    1     170      53           105           149           362
#
#      t_interval  p_interval  qrs  ...     KT    KU   KV   KY    KZ   LA   LD  \
# 405         154          87   84  ...   18.8  41.7  0.2  0.0   7.5  0.0 -0.1
# 125         206          84   56  ...   22.2  51.3  0.1 -0.4   9.7 -0.7  0.5
# 135         160          89   81  ...   31.0  48.1 -0.1  0.0  11.3  0.0  0.8
# 421         139         100   25  ...    7.5   8.6 -0.4  0.0   7.6 -2.2  0.8
# 250         143          82  -38  ...   -3.1  13.7  0.1 -0.6   8.7 -3.9  0.5
#
#       LE    LF    LG
# 405  2.5  28.5  49.0
# 125  2.6  22.2  49.2
# ...

# %%
print("x_train: ",x_train.shape)
print("y_train: ",y_train.shape)
print("x_test: ",x_test.shape)
print("y_test: ",y_test.shape)
print("x_validate: ",x_test.shape)
print("y_validate: ",y_test.shape)
# Out:
# x_train:  (270, 176)
# y_train:  (270,)
# x_test:  (91, 176)
# y_test:  (91,)
# x_validate:  (91, 176)
# y_validate:  (91,)

# %% [markdown]
# By calling the Naive Bayes Algorithm from the SkitLearn library, the algorithm is trained with x_train and y_train values.

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
x_test=data.head(2)
x_test=x_test.drop(["diagnosis"],axis=1)

# %%
x_test
# Out:
#    age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
#
#    t_interval  p_interval  qrs  ...     KT    KU   KV   KY   KZ   LA   LD  \
# 0         174         121  -16  ...   25.5  62.9 -0.3  0.0  9.0 -0.9  0.9
# 1         149          39   25  ...   21.6  43.4 -0.5  0.0  8.5  0.0  0.2
#
#     LE    LF    LG
# 0  2.9  23.3  49.4
# 1  2.1  20.4  38.8
#
# [2 rows x 176 columns]

# %%
y_pred = nb.predict(x_test)
print("Estimated Value: ",y_pred)
# Out:
# Estimated Value:  [8 6]

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
print("Confussion Matrix: ",confusion_matrix(y_test, y_pred))
print("Accuracy rate: ",metrics.accuracy_score(y_test,y_pred))
print("f1 Score: ",f1_score(y_test, y_pred, average='macro'))
print("Accuracy Value: ",precision_score(y_test, y_pred, average='macro'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0fdca14ed8c8> in <module>
#       3 from sklearn.metrics import f1_score
#       4 from sklearn.metrics import precision_score
# ----> 5 print("Confussion Matrix: ",confusion_matrix(y_test, y_pred))
#       6 print("Accuracy rate: ",metrics.accuracy_score(y_test,y_pred))
#       7 print("f1 Score: ",f1_score(y_test, y_pred, average='macro'))
#
# F:\Anaconda\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# F:\Anaconda\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
# ...

# %%
data.diagnosis.values
